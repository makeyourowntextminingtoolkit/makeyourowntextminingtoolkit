# %%
# notebook to illustrate co-occurrence graphs

# %%
# following only used for development, reloads the modules with any code changes
# %load_ext autoreload
# %autoreload 2

# inline matplotlib charts
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import our text mining toolkit
import text_mining_toolkit as tmt

# %%
cr = tmt.corpus_reader.CorpusReader(content_directory="data_sets/recipes/txt/", text_filename_pattern="??.txt")
#cr = tmt.corpus_reader.CorpusReader(directory_of_files="data_sets/mystery_corpus_01/txt/", text_filename_pattern="??.txt")
#cr = tmt.corpus_reader.CorpusReader(content_directory="data_sets/iraq_inquiry/txt/", text_filename_pattern="the-report*.txt")
#cr = tmt.corpus_reader.CorpusReader(content_directory="data_sets/clinton_emails/txt/", text_filename_pattern="C0*")
#cr = tmt.corpus_reader.CorpusReader(content_directory="data_sets/shakespeare_macbeth/txt/", text_filename_pattern="macbeth_act_0?_scene_0?.txt")
# Out:
# content_directory =  data_sets/recipes/txt/
# text_filename_pattern =  ??.txt
# self.documents populated =  22

# %%
# load previously calculated relevance scores
words_by_relevance = tmt.index_search.get_words_by_relevance(cr.content_directory)
# top most relevant
top_words_by_relevance = words_by_relevance[:100]

# %%
# first clear index
tmt.cooccurrence.delete_matrices(cr.content_directory)

# for all documents in corpus
for document_name in cr.get_documents():
    print("processing ", document_name)

    # get document text
    document_text = cr.get_text_by_document(document_name)

    # simplify whitespace (remove newlines)
    b = tmt.text_processing.simplify_whitespace(document_text)

    # only keep alphanumeric characters, removes punctuation
    c = tmt.text_processing.keep_alphanumeric(b)

    # make lowercase
    d = tmt.text_processing.to_lowercase(c)

    # split into words list
    dl = tmt.text_processing.split_text_into_words(d)
    # build n-grams
    #gl = tmt.word_processing.build_ngrams_from_words(dl,2)

    # remove stop words
    #el = tmt.word_processing.remove_stop_words(dl, "./stopwords/minimal-stop.txt")
    
    # remove all except those in the top most relevant list
    el = [word for word in dl if word in top_words_by_relevance]
    
    # update index
    tmt.cooccurrence.create_cooccurrence_matrix_for_document(cr.content_directory, document_name, el, window=3)
    pass
# Out:
# removed co-occurrence matrix file:  data_sets/recipes/txt/matrix.cooccurrence
# processing  00.txt
# processing  01.txt
# processing  02.txt
# processing  03.txt
# processing  04.txt
# processing  05.txt
# processing  06.txt
# processing  07.txt
# processing  08.txt
# processing  09.txt
# processing  10.txt
# processing  11.txt
# processing  12.txt
# processing  13.txt
# processing  14.txt
# processing  15.txt
# processing  16.txt
# processing  17.txt
# processing  18.txt
# processing  19.txt
# processing  20.txt
# processing  21.txt

# %%
# merge document indices into a corpus index
tmt.cooccurrence.merge_cooccurrence_matrices_for_corpus(cr.content_directory)
# Out:
# saving corpus co-occurrence matrix ...  data_sets/recipes/txt/matrix.cooccurrence

# %%
tmt.cooccurrence.print_matrix(cr.content_directory)
# Out:
# cooccurrence_matrix_file  data_sets/recipes/txt/matrix.cooccurrence
#                  add  adding    ...        whole      with
# add         0.000000     0.0    ...     0.000000  0.735759
# adding      0.000000     0.0    ...     0.000000  0.641180
# after       0.367879     0.0    ...     0.000000  1.262719
# are         0.000000     0.0    ...     0.000000  0.735759
# artichokes  0.000000     0.0    ...     0.000000  0.000000
# as          0.000000     0.0    ...     0.367879  0.894839
# asparagus   0.000000     0.0    ...     0.000000  1.009060
# boiled      0.641180     0.0    ...     0.000000  1.009060
# boiling     0.000000     0.0    ...     0.000000  0.000000
# bread       0.000000     0.0    ...     0.000000  2.157558
#
# [10 rows x 100 columns]

# %%
# query the co-occurrence value for a given pair of words
#tmt.cooccurrence.query_cooccurance_matrix(cr.content_directory, "in", "the")

# %%
# get the most likely next word by co-occurrence value for given word
#tmt.cooccurrence.most_likely_next(cr.content_directory, "and")

# %%
#generate sentences based on co-occurence
sentence_length = 7

#initial words 
#for w in ["the", "once", "then", "olive", "tomato", "cut", "cook", "little", "boiled"]:
for w in ["butter"]:
    sentence = w
    for i in range(sentence_length):
        w = tmt.cooccurrence.most_likely_next(cr.content_directory, w)
        sentence += (" " + w)
        pass
    print(sentence)
    pass
# Out:
# butter when are to it is to it

# %%
words_by_co_occurrence = tmt.cooccurrence.get_word_pairs_by_cooccurrence(cr.content_directory)
# 20 most common
words_by_co_occurrence[:20]
# Out:
#        word1   word2     weight
# 0     grated  cheese  14.317429
# 1         it      is  14.158349
# 2       with  butter  11.259456
# 3       they     are   9.957453
# 4        cut    them   9.583998
# 5       them    with   8.256777
# 6         to      it   7.615597
# 7         or      or   7.476158
# 8         is      to   7.387156
# 9     tomato   sauce   7.158715
# 10      with      or   6.929556
# 11        or    with   6.606537
# 12      them    them   6.606537
# 13      with  pepper   6.492316
# 14  seasoned    with   6.263875
# 15    season    with   5.736915
# 16    cheese      or   5.597477
# 17      when     are   5.383102
# 18      this   sauce   5.369036
# 19     brown   stock   5.369036

# %%
# 20 least common
words_by_co_occurrence[-20:]
# Out:
#          word1   word2    weight
# 2322     olive    they  0.367879
# 2323     olive   sauce  0.367879
# 2324       oil   three  0.367879
# 2325        is     but  0.367879
# 2326    cooked   three  0.367879
# 2327    cooked  pepper  0.367879
# 2328    cooked    make  0.367879
# 2329       two    into  0.367879
# 2330      they     but  0.367879
# 2331    cooked     cut  0.367879
# 2332     olive     for  0.367879
# 2333    cooked   bread  0.367879
# 2334       two  leaves  0.367879
# 2335  composed    when  0.367879
# 2336       fry    with  0.367879
# 2337  composed  pieces  0.367879
# 2338    frying   after  0.367879
# 2339  composed  grated  0.367879
# 2340       two     oil  0.367879
# 2341     olive      or  0.367879

# %%
# visualise co-occurrence of words
tmt.visualisation.plot_force_directed_graph(words_by_co_occurrence[:500])
# Out:
# <div id="d3-container-5168802"></div>
# <div>force-directed graph</div>
#
# <style>
#     .links line {
#         stroke: #999;
#         stroke-opacity: .2;
#     }
#
#     .nodes circle {
#         pointer-events: all;
#         stroke: #fff;
#         stroke-width: 1.5px;
#     }
#
#     .nodes text {
#         pointer-events: none;
#         font: 10px sans-serif;
#         fill: #000000;
#         opacity: .7;
#     }
# </style>

# %%
# visualise co-occurrence > 1
w = words_by_co_occurrence[words_by_co_occurrence['weight']>5]
tmt.visualisation.plot_force_directed_graph(w)
# Out:
# <div id="d3-container-8885459"></div>
# <div>force-directed graph</div>
#
# <style>
#     .links line {
#         stroke: #999;
#         stroke-opacity: .2;
#     }
#
#     .nodes circle {
#         pointer-events: all;
#         stroke: #fff;
#         stroke-width: 1.5px;
#     }
#
#     .nodes text {
#         pointer-events: none;
#         font: 10px sans-serif;
#         fill: #000000;
#         opacity: .7;
#     }
# </style>
